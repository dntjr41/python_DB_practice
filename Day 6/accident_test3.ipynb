# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc

# %%
#한글깨짐 방지작업
font_info="C:/Users/LG/Jupyter workspace/Day 6/malgun.ttf"
font_name=font_manager.FontProperties(fname=font_info).get_name()
rc('font', family=font_name)

# %%
data = pd.read_csv('accidentdata.csv')

# %%
d_pv = pd.crosstab(data['요일'], data['발생지시도'])
d_pv
# Out:
# 발생지시도   강원   경기   경남   경북  광주  대구  대전  부산   서울  세종  울산  인천   전남   전북  제주   충남  \
# 요일
# 금      101  379  205  239  48  76  50  75  174   6  41  70  181  162  41  169
# 목      108  404  177  216  41  78  42  89  174  10  43  79  170  134  42  173
# 수      106  390  185  210  41  71  41  81  171   8  41  68  192  122  49  162
# 월      102  400  211  225  40  69  47  85  174   5  60  66  195  165  28  189
# 일       93  377  150  193  36  90  31  88  137   4  41  47  128  129  40  156
# 토       85  417  189  198  59  87  54  95  172   7  55  76  210  137  38  181
# 화      108  410  185  230  46  74  45  83  171  13  49  80  198  158  37  158
#
# 발생지시도   충북
# 요일
# 금      104
# 목      115
# 수      104
# 월      120
# 일      106
# 토      116
# 화      118

# %%
result = d_pv.div(d_pv.sum(1).astype(float),axis=0)
result
# Out:
# 발생지시도        강원        경기        경남        경북        광주        대구        대전  \
# 요일
# 금      0.047619  0.178689  0.096653  0.112683  0.022631  0.035832  0.023574
# 목      0.051551  0.192840  0.084487  0.103103  0.019570  0.037232  0.020048
# 수      0.051910  0.190989  0.090597  0.102840  0.020078  0.034770  0.020078
# 월      0.046768  0.183402  0.096745  0.103164  0.018340  0.031637  0.021550
# 일      0.050379  0.204225  0.081257  0.104550  0.019502  0.048754  0.016793
# 토      0.039062  0.191636  0.086857  0.090993  0.027114  0.039982  0.024816
# 화      0.049931  0.189552  0.085529  0.106334  0.021267  0.034212  0.020804
#
# 발생지시도        부산        서울        세종        울산        인천        전남        전북  \
# 요일
# 금      0.035361  0.082037  0.002829  0.019331  0.033003  0.085337  0.076379
# 목      0.042482  0.083055  0.004773  0.020525  0.037709  0.081146  0.063962
# 수      0.039667  0.083741  0.003918  0.020078  0.033301  0.094025  0.059745
# 월      0.038973  0.079780  0.002293  0.027510  0.030261  0.089409  0.075653
# 일      0.047671  0.074215  0.002167  0.022210  0.025460  0.069339  0.069881
# 토      0.043658  0.079044  0.003217  0.025276  0.034926  0.096507  0.062960
# 화      0.038373  0.079057  0.006010  0.022654  0.036986  0.091540  0.073047
#
# 발생지시도        제주        충남        충북
# 요일
# 금      0.019331  0.079679  0.049033
# 목      0.020048  0.082578  0.054893
# 수      0.023996  0.079334  0.050930
# 월      0.012838  0.086657  0.055021
# 일      0.021668  0.084507  0.057421
# 토      0.017463  0.083180  0.053309
# 화      0.017106  0.073047  0.054554

# %%
result.plot(kind='bar', stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='요일'>

# %%
#발생지시도별 교통사고 요일분석
d_pv1 = pd.crosstab(data['발생지시도'], data['요일'])
d_pv1
# Out:
# 요일       금    목    수    월    일    토    화
# 발생지시도
# 강원     101  108  106  102   93   85  108
# 경기     379  404  390  400  377  417  410
# 경남     205  177  185  211  150  189  185
# 경북     239  216  210  225  193  198  230
# 광주      48   41   41   40   36   59   46
# 대구      76   78   71   69   90   87   74
# 대전      50   42   41   47   31   54   45
# 부산      75   89   81   85   88   95   83
# 서울     174  174  171  174  137  172  171
# 세종       6   10    8    5    4    7   13
# 울산      41   43   41   60   41   55   49
# 인천      70   79   68   66   47   76   80
# 전남     181  170  192  195  128  210  198
# 전북     162  134  122  165  129  137  158
# 제주      41   42   49   28   40   38   37
# 충남     169  173  162  189  156  181  158
# 충북     104  115  104  120  106  116  118

# %%
result1 = d_pv1.div(d_pv1.sum(1).astype(float),axis=0)
result1
# Out:
# 요일            금         목         수         월         일         토         화
# 발생지시도
# 강원     0.143670  0.153627  0.150782  0.145092  0.132290  0.120910  0.153627
# 경기     0.136478  0.145481  0.140439  0.144040  0.135758  0.150162  0.147641
# 경남     0.157450  0.135945  0.142089  0.162058  0.115207  0.145161  0.142089
# 경북     0.158173  0.142952  0.138981  0.148908  0.127730  0.131039  0.152217
# 광주     0.154341  0.131833  0.131833  0.128617  0.115756  0.189711  0.147910
# 대구     0.139450  0.143119  0.130275  0.126606  0.165138  0.159633  0.135780
# 대전     0.161290  0.135484  0.132258  0.151613  0.100000  0.174194  0.145161
# 부산     0.125839  0.149329  0.135906  0.142617  0.147651  0.159396  0.139262
# 서울     0.148338  0.148338  0.145780  0.148338  0.116795  0.146633  0.145780
# 세종     0.113208  0.188679  0.150943  0.094340  0.075472  0.132075  0.245283
# 울산     0.124242  0.130303  0.124242  0.181818  0.124242  0.166667  0.148485
# 인천     0.144033  0.162551  0.139918  0.135802  0.096708  0.156379  0.164609
# 전남     0.142072  0.133438  0.150706  0.153061  0.100471  0.164835  0.155416
# 전북     0.160874  0.133069  0.121152  0.163853  0.128103  0.136048  0.156902
# 제주     0.149091  0.152727  0.178182  0.101818  0.145455  0.138182  0.134545
# 충남     0.142256  0.145623  0.136364  0.159091  0.131313  0.152357  0.132997
# 충북     0.132822  0.146871  0.132822  0.153257  0.135377  0.148148  0.150702

# %%
result1.plot(kind='bar', stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='발생지시도'>
