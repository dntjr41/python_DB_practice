# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy.random as nrp

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="958.5185862307079">

# %%
a1 = fig.add_subplot(1,1,1)
a1.plot(nrp.randn(50), 'b*--')
a1.set_xlim([1,50])
a1.set_ylim([-1,3])
a1.set_title('basic graph')
# Out:
# Text(0.5, 1.0, 'basic graph')
