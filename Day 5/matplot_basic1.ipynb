# %%
import matplotlib.pyplot as plt

# %%
plt.plot([10,20,30,40,50])
plt.show()

# %%
plt.plot([2015,2016,2017],[3.2,2.8,3.6])
plt.show()

# %%
plt.plot([12,15.3,10.9,14,16], 'ro-')
plt.show()

# %%
plt.plot([12,15.3,10.9,14,16], color='b', linestyle='dashed', marker='+')
plt.show()
