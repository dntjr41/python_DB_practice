# %%
# %matplotlib notebook
import numpy.random as rp
import matplotlib.pyplot as plt

# %%
r_img = rp.random([500, 500])
r_img
# Out:
# array([[0.80591654, 0.68465129, 0.01771871, ..., 0.16441002, 0.53603869,
#         0.668914  ],
#        [0.4438453 , 0.09859743, 0.9209886 , ..., 0.80600388, 0.18184241,
#         0.86272887],
#        [0.16317235, 0.07220059, 0.52516308, ..., 0.39512246, 0.38214958,
#         0.24397033],
#        ...,
#        [0.4494249 , 0.62571866, 0.26787012, ..., 0.44893343, 0.89392032,
#         0.12966189],
#        [0.98502804, 0.14497261, 0.42568267, ..., 0.60986446, 0.19401162,
#         0.22172563],
#        [0.85078016, 0.44970856, 0.24348889, ..., 0.13514695, 0.44600708,
#         0.25236625]])

# %%
plt.imshow(r_img, cmap='gray',interpolation='nearest')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a = rp.randn(100)
a
# Out:
# array([-0.06871067, -1.0269052 , -0.79536856, -0.61464482,  1.40790554,
#        -0.3535795 , -0.2943062 , -0.82501128,  0.15667344, -0.43990115,
#         0.87549967,  0.50409718,  0.51074161,  0.04302879, -0.7865231 ,
#        -0.32338439,  1.53891151, -0.06772634, -0.7874589 ,  0.14083114,
#         0.02501227, -0.48740592, -3.11203263,  0.94581843, -0.58217009,
#         2.88985102, -0.22588396, -0.15284243, -0.86852203,  2.0770695 ,
#         0.51678751,  0.81123215,  1.65282996, -0.3713879 ,  1.05661284,
#         0.17095515,  0.6621994 , -1.32153592,  0.1140882 ,  1.15286257,
#        -0.97187542,  1.00617051,  1.69925506, -0.29374314, -1.34403843,
#         0.60166796, -0.21331735, -0.16102913,  0.64243483, -0.65626642,
#        -1.2055253 ,  1.38349757,  1.12066331,  0.91149639,  0.93798514,
#        -0.2760439 ,  1.42667396,  0.37406132,  0.19289263, -0.14119683,
#        -0.86334908, -1.39327689,  0.0730624 ,  0.07977367, -0.00637235,
# ...

# %%
plt.plot(a)
# Out:
# <img src="data:image/png;base64,..." width="640">
